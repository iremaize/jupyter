# %%
import pandas as pd
from scipy import stats
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
kg0_e = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\01deg_0kg_E5.csv', skiprows=6)
kg0_g = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\01deg_0kg_E6.csv', skiprows=6)
kg2_e = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\01deg_2kg_E5.csv', skiprows=6)
kg2_g = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\01deg_2kg_E6.csv', skiprows=6)
d_kg0_e = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\diamond_01deg_0kg_E5.csv', skiprows=6)
d_kg0_g = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\diamond_01deg_0kg_E6.csv', skiprows=6)
d_kg2_e = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\diamond_01deg_2kg_E5.csv', skiprows=6)
d_kg2_g = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\diamond_01deg_2kg_E6.csv', skiprows=6)

# %%
for i in [kg0_e, kg0_g, kg2_e, kg2_g, d_kg0_e, d_kg0_g, d_kg2_e, d_kg2_g]:
    i.drop([0,101], inplace=True)

# %%
# Out:
#      entries    Sw   Sw2     Sxw0       Sx2w0
# 1       1241  1241  1241  2472.28     7187.52
# 2        495   495   495  3551.79    26497.10
# 3        260   260   260  3193.11    39776.20
# 4        218   218   218  3799.51    66674.20
# 5        163   163   163  3655.42    82306.30
# ..       ...   ...   ...      ...         ...
# 96        14    14    14  6684.17  3191330.00
# 97        15    15    15  7239.85  3494400.00
# 98        19    19    19  9263.72  4516700.00
# 99        20    20    20  9842.38  4843660.00
# 100       13    13    13  6464.63  3214750.00
#
# [100 rows x 5 columns]

# %%
df = pd.DataFrame()

# %%
k=0
for i in [kg0_e, kg0_g, kg2_e, kg2_g, d_kg0_e, d_kg0_g, d_kg2_e, d_kg2_g]:
    df[str(k)]=i.entries
    k=int(k)+1

# %%
for i in df[['kg0_g', 'kg2_g','d_kg0_g', 'd_kg2_g']]:
        f = sns.lineplot(data=df, x='energy', y=i, label=i)
        plt.legend()
#f.set(yscale="log")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6752/618637429.py in <module>
# ----> 1 for i in df[['kg0_g', 'kg2_g','d_kg0_g', 'd_kg2_g']]:
#       2         f = sns.lineplot(data=df, x='energy', y=i, label=i)
#       3         plt.legend()
#       4 #f.set(yscale="log")
#
# c:\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
# ...

# %%
df
# Out:
#         0      1    2      3     4      5    6      7
# 1    1241  29102  279  13649  1226  28747  293  13648
# 2     495   6174   95   3432   449   6167  105   3487
# 3     260   3458   58   1948   239   3457   53   1962
# 4     218   2425   42   1330   197   2449   71   1325
# 5     163   1839   37   1028   194   1788   41    960
# ..    ...    ...  ...    ...   ...    ...  ...    ...
# 96     14     29    4     32    18     42    0     36
# 97     15     41    1     23    12     31    4     24
# 98     19     33    2     28    15     32    1     25
# 99     20     40    3     32    14     37    0     30
# 100    13     41    2     27    15     28    1     28
#
# [100 rows x 8 columns]

# %%
data = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\hist1.root', skiprows=6)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24712/4195484231.py in <module>
# ----> 1 data = pd.read_csv(r'C:\\Users\\01\\Desktop\\GENERAL_ACCES\\hists\\hist1.root', skiprows=6)
#
# c:\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
